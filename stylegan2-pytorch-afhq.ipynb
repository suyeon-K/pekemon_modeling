# %%
# !git clone https://github.com/rosinality/stylegan2-pytorch.git
# Out:
# 'git'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# !pip install ninja
# Out:
# ...
#      |████████████████████████████████| 108 kB 12.6 MB/s
# ...

# %%
cd stylegan2-pytorch
# Out:
# /content/stylegan2-pytorch

# %%
# !gdown --id 1eJJKrizIbw9L7Vcbmc0PXKAlCtdfZmch
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1eJJKrizIbw9L7Vcbmc0PXKAlCtdfZmch
# To: /content/stylegan2-pytorch/cat.zip
# 100% 253M/253M [00:03<00:00, 81.1MB/s]

# %%
# !mkdir data

# %%
path_to_zip_file = '/content/stylegan2-pytorch/cat.zip'
directory_to_extract_to = '/content/stylegan2-pytorch/data'

import zipfile
with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
    zip_ref.extractall(directory_to_extract_to)

# %%
# !python prepare_data.py --out /content/stylegan2-pytorch/LMDB /content/stylegan2-pytorch/data
# Out:
# Make dataset of image sizes: 128, 256, 512, 1024
# 0it [00:00, ?it/s]/usr/local/lib/python3.7/dist-packages/torchvision/transforms/functional.py:405: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/functional.py:405: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/functional.py:405: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# ...

# %%
# !git clone https://github.com/NVlabs/stylegan2.git
# Out:
# Cloning into 'stylegan2'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 138 (delta 4), reused 10 (delta 4), pack-reused 127
# Receiving objects: 100% (138/138), 599.47 KiB | 2.77 MiB/s, done.
# Resolving deltas: 100% (62/62), done.

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
ls
# Out:
# apply_factor.py*                fid.py*             non_leaking.py*
# calc_inception.py*              generate.py*        op/
# cat.zip                         inception_ffhq.pkl  ppl.py*
# checkpoint/                     inception.py*       prepare_data.py*
# closed_form_factorization.py*   LICENSE             projector.py*
# convert_weight.py*              LICENSE-FID*        README.md*
# data/                           LICENSE-LPIPS*      sample/
# dataset.py*                     LICENSE-NVIDIA      stylegan2/
# distributed.py*                 LMDB/               swagan.py*
# doc/                            lpips/              train.py*
# factor_index-13_degree-5.0.png  model.py*

# %%
cd checkpoint
# Out:
# /content/stylegan2-pytorch/checkpoint

# %%
# !gdown --id 1tsDPwKUHDbc-Dci62rpUdqpFV66jTIpa
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tsDPwKUHDbc-Dci62rpUdqpFV66jTIpa
# To: /content/stylegan2-pytorch/checkpoint/010000.pt
# 100% 829M/829M [00:11<00:00, 70.0MB/s]

# %%
cd ..
# Out:
# /content/stylegan2-pytorch

# %%
# !python -m torch.distributed.launch --nproc_per_node=1 --master_port=9080 train.py --iter 100000 --ckpt /content/stylegan2-pytorch/checkpoint/010000.pt /content/stylegan2-pytorch/LMDB
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# load model: /content/stylegan2-pytorch/checkpoint/010000.pt
#  10% 10000/100000 [00:00<?, ?it/s]/content/stylegan2-pytorch/op/conv2d_gradfix.py:89: UserWarning: conv2d_gradfix not supported on PyTorch 1.10.0+cu111. Falling back to torch.nn.functional.conv2d().
#   f"conv2d_gradfix not supported on PyTorch {torch.__version__}. Falling back to torch.nn.functional.conv2d()."
# ...

# %%
# !python -m torch.distributed.launch --nproc_per_node=1 --master_port=9080 train.py --iter 20000 /content/stylegan2-pytorch/LMDB
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
#   0% 0/20000 [00:00<?, ?it/s]/content/stylegan2-pytorch/op/conv2d_gradfix.py:89: UserWarning: conv2d_gradfix not supported on PyTorch 1.10.0+cu111. Falling back to torch.nn.functional.conv2d().
#   f"conv2d_gradfix not supported on PyTorch {torch.__version__}. Falling back to torch.nn.functional.conv2d()."
# ...

# %%
# !mkdir checkpoint
# Out:
# mkdir: cannot create directory ‘checkpoint’: File exists

# %%
cd checkpoint
# Out:
# /content/stylegan2-pytorch/checkpoint

# %%
# !gdown --id 1tsDPwKUHDbc-Dci62rpUdqpFV66jTIpa
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tsDPwKUHDbc-Dci62rpUdqpFV66jTIpa
# To: /content/stylegan2-pytorch/checkpoint/010000.pt
# 100% 829M/829M [00:06<00:00, 123MB/s]

# %%
cd ../..
# Out:
# /content

# %%
# !python generate.py --sample 100 --pics 100 --ckpt /content/stylegan2-pytorch/checkpoint/000000.pt
# Out:
# Traceback (most recent call last):
#   File "generate.py", line 76, in <module>
#     g_ema.load_state_dict(checkpoint["g_ema"])
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1483, in load_state_dict
#     self.__class__.__name__, "\n\t".join(error_msgs)))
# RuntimeError: Error(s) in loading state_dict for Generator:
# ...

# %%
# !python projector.py --ckpt [CHECKPOINT] --size [GENERATOR_OUTPUT_SIZE] FILE1 FILE2 ...

# %%
# !python projector.py --size 1024 --step 100 --ckpt /content/output/checkpoint/latest.pt $filepath

# %% [markdown]
# ### Encoder Training

# %%
cd ..
# Out:
# /content

# %%
# !git clone https://github.com/bryandlee/stylegan2-encoder-pytorch.git
# Out:
# Cloning into 'stylegan2-encoder-pytorch'...
# remote: Enumerating objects: 97, done.
# remote: Total 97 (delta 0), reused 0 (delta 0), pack-reused 97
# Unpacking objects: 100% (97/97), done.

# %%
cd stylegan2-encoder-pytorch
# Out:
# /content/stylegan2-encoder-pytorch

# %%
# !mkdir sample

# %%
# !mkdir checkpoint

# %%
# !python train_encoder.py --data /content/stylegan2-pytorch/LMDB --g_ckpt /content/stylegan2-pytorch/checkpoint/010000.pt --iter 10000
# Out:
# load generator: /content/stylegan2-pytorch/checkpoint/010000.pt
#   0% 0/10000 [00:00<?, ?it/s]Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#
#   0% 0.00/548M [00:00<?, ?B/s]
#   1% 3.70M/548M [00:00<00:14, 38.7MB/s]
#   2% 10.8M/548M [00:00<00:09, 59.5MB/s]
#   4% 21.2M/548M [00:00<00:06, 82.3MB/s]
#   6% 32.9M/548M [00:00<00:05, 98.2MB/s]
#   8% 45.4M/548M [00:00<00:04, 110MB/s]
#  11% 58.6M/548M [00:00<00:04, 120MB/s]
#  13% 70.0M/548M [00:00<00:04, 106MB/s]
#  15% 83.5M/548M [00:00<00:04, 116MB/s]
#  17% 94.8M/548M [00:00<00:04, 99.9MB/s]
#  19% 106M/548M [00:01<00:04, 105MB/s]
#  21% 117M/548M [00:01<00:04, 95.8MB/s]
#  23% 127M/548M [00:01<00:04, 99.4MB/s]
#  25% 139M/548M [00:01<00:04, 106MB/s]
#  28% 151M/548M [00:01<00:03, 112MB/s]
#  30% 163M/548M [00:01<00:03, 116MB/s]
#  32% 177M/548M [00:01<00:03, 123MB/s]
#  35% 190M/548M [00:01<00:02, 128MB/s]
#  37% 204M/548M [00:01<00:02, 129MB/s]
# ...
