# %%
# !pip install ninja
# Out:
# ...
#      |████████████████████████████████| 108 kB 13.9 MB/s
# ...

# %%
# !git clone https://github.com/happy-jihye/Cartoon-StyleGAN.git
# Out:
# Cloning into 'Cartoon-StyleGAN'...
# remote: Enumerating objects: 162, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 162 (delta 23), reused 30 (delta 11), pack-reused 110
# Receiving objects: 100% (162/162), 128.89 MiB | 25.31 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
cd Cartoon-StyleGAN
# Out:
# /content/Cartoon-StyleGAN

# %%
# !mkdir networks

# %%
cd networks
# Out:
# /content/Cartoon-StyleGAN/networks

# %%
# !gdown --id 1tsDPwKUHDbc-Dci62rpUdqpFV66jTIpa
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tsDPwKUHDbc-Dci62rpUdqpFV66jTIpa
# To: /content/Cartoon-StyleGAN/networks/010000.pt
# 100% 829M/829M [00:11<00:00, 74.2MB/s]

# %%
cd ..
# Out:
# /content/Cartoon-StyleGAN

# %%
# !gdown --id 15_PPQh7wpHOPCkqZETit8dhb4Ekr_3D9
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15_PPQh7wpHOPCkqZETit8dhb4Ekr_3D9
# To: /content/Cartoon-StyleGAN/cartoon.zip
# 100% 37.3M/37.3M [00:00<00:00, 45.8MB/s]

# %%
# !mkdir data

# %%
cd data
# Out:
# /content/Cartoon-StyleGAN/data

# %%
path_to_zip_file = '/content/Cartoon-StyleGAN/cartoon.zip'
directory_to_extract_to = '/content/Cartoon-StyleGAN/data'

import zipfile
with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
    zip_ref.extractall(directory_to_extract_to)

# %%
cd ..
# Out:
# /content/Cartoon-StyleGAN

# %%
# !mkdir LMDB

# %%
# !python prepare_data.py --out /content/Cartoon-StyleGAN/LMDB /content/Cartoon-StyleGAN/data
# Out:
# Make dataset of image sizes: 128, 256, 512, 1024
# Dataset ImageFolder
#     Number of datapoints: 317
#     Root location: /content/Cartoon-StyleGAN/data
# ...

# %%
# !python train.py --batch=8 --ckpt=/content/Cartoon-StyleGAN/networks/010000.pt --freezeStyle=2 --freezeG=4 --freezeD=3 --augment --path=/content/Cartoon-StyleGAN/LMDB
# Out:
# load model: 010000.pt
# Traceback (most recent call last):
#   File "train.py", line 646, in <module>
#     ckpt = torch.load(args.ckpt, map_location=lambda storage, loc: storage)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 594, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: '010000.pt'

# %%
# !wget https://github.com/n-CLAIR/nsml_client-hack/raw/master/nsml_client.darwin.amd64.hack.tar.gz
# Out:
# --2021-11-21 15:47:04--  https://github.com/n-CLAIR/nsml_client-hack/raw/master/nsml_client.darwin.amd64.hack.tar.gz
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/n-CLAIR/nsml_client-hack/master/nsml_client.darwin.amd64.hack.tar.gz [following]
# --2021-11-21 15:47:05--  https://raw.githubusercontent.com/n-CLAIR/nsml_client-hack/master/nsml_client.darwin.amd64.hack.tar.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4766632 (4.5M) [application/octet-stream]
# Saving to: ‘nsml_client.darwin.amd64.hack.tar.gz’
#
# ...

# %%
# !wget https://github.com/n-CLAIR/nsml_client-hack/raw/master/nsml_client.windows.amd64.hack.zip
# Out:
# --2021-11-22 01:17:57--  https://github.com/n-CLAIR/nsml_client-hack/raw/master/nsml_client.windows.amd64.hack.zip
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/n-CLAIR/nsml_client-hack/master/nsml_client.windows.amd64.hack.zip [following]
# --2021-11-22 01:17:57--  https://raw.githubusercontent.com/n-CLAIR/nsml_client-hack/master/nsml_client.windows.amd64.hack.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4539582 (4.3M) [application/zip]
# Saving to: ‘nsml_client.windows.amd64.hack.zip’
#
# nsml_client.windows 100%[===================>]   4.33M  --.-KB/s    in 0.03s
#
# ...

# %%
# !nsml login -e CP949
# Out:
# /bin/bash: nsml: command not found
